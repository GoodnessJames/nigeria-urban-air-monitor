# %% [markdown]
# # Nigeria Urban Air Monitor — Google Colab
#
# This notebook runs the GitHub-ready Streamlit dashboard and tests the data pipeline.

# %% [markdown]
# ## 1. Install project dependencies
#
# This supports Core Requirements 1–3.

# %%
# !pip install -q -r requirements.txt

# %% [markdown]
# ## 2. Test Core Requirement 1 — Automated Data Ingestion

# %%
# !python ingestion_client.py --once

# %% [markdown]
# ## 3. Launch the Streamlit dashboard
#
# The dashboard performs the historical backfill on first startup and then refreshes live ingestion every 60 seconds while the session is active.

# %%
# !streamlit run app.py --server.headless true --server.port 8501 > streamlit.log 2>&1 &

# %% [markdown]
# ## 4. Create a temporary public Colab URL
#
# This is only for testing the app from Colab. The final public deployment should use Streamlit Community Cloud from GitHub.

# %%
# !npm install -g localtunnel
# !lt --port 8501
